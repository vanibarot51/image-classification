# %% [markdown]
# <a href="https://colab.research.google.com/github/vanibarot51/image-classification/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip pepsibishop.zip
# Out:
# Archive:  pepsibishop.zip
#    creating: pepsibishop/test/
#    creating: pepsibishop/test/Bishop/
#   inflating: pepsibishop/test/Bishop/00000062.jpg
#   inflating: pepsibishop/test/Bishop/00000086.png
#   inflating: pepsibishop/test/Bishop/00000088.jpg
#   inflating: pepsibishop/test/Bishop/00000089.jpg
#   inflating: pepsibishop/test/Bishop/00000092.jpg
#   inflating: pepsibishop/test/Bishop/00000127.jpg
#   inflating: pepsibishop/test/Bishop/00000129.jpg
#   inflating: pepsibishop/test/Bishop/00000130.png
#   inflating: pepsibishop/test/Bishop/00000136.png
#   inflating: pepsibishop/test/Bishop/00000167.jpg
#   inflating: pepsibishop/test/Bishop/00000168.jpg
#   inflating: pepsibishop/test/Bishop/00000169.jpg
#   inflating: pepsibishop/test/Bishop/00000174.jpg
#   inflating: pepsibishop/test/Bishop/00000189.jpg
#   inflating: pepsibishop/test/Bishop/00000192.jpg
#   inflating: pepsibishop/test/Bishop/00000193.jpg
#   inflating: pepsibishop/test/Bishop/00000194.jpg
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
img_height, img_width = 32,32
batch_size = 20

train_ds = tf.keras.utils.image_dataset_from_directory(
      "pepsibishop/train",
      image_size = (img_height, img_width),
      batch_size = batch_size
)
val_ds = tf.keras.utils.image_dataset_from_directory(
      "pepsibishop/validation",
      image_size = (img_height, img_width),
      batch_size = batch_size
)
test_ds = tf.keras.utils.image_dataset_from_directory(
      "pepsibishop/test",
      image_size = (img_height, img_width),
      batch_size = batch_size
)
# Out:
# Found 62 files belonging to 2 classes.
# Found 58 files belonging to 2 classes.
# Found 48 files belonging to 2 classes.

# %%
class_names = ["Bishop","pepsi"]
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
model = tf.keras.Sequential(
    [
        tf.keras.layers.Rescaling(1./255),
        tf.keras.layers.Conv2D(32, 3, activation="relu"),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(32, 3, activation="relu"),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(32, 3, activation="relu"),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dense(3)

    ]
)

# %%
model.compile(
    optimizer="adam",
    loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"]
)

# %%
model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 10
)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 2s 186ms/step - loss: 1.0381 - accuracy: 0.4194 - val_loss: 0.8307 - val_accuracy: 0.5517
# Epoch 2/10
# 4/4 [==============================] - 0s 62ms/step - loss: 0.7666 - accuracy: 0.5806 - val_loss: 0.6846 - val_accuracy: 0.5517
# Epoch 3/10
# 4/4 [==============================] - 1s 113ms/step - loss: 0.6534 - accuracy: 0.7258 - val_loss: 0.6338 - val_accuracy: 0.8793
# Epoch 4/10
# 4/4 [==============================] - 0s 60ms/step - loss: 0.5727 - accuracy: 0.9516 - val_loss: 0.5582 - val_accuracy: 0.6379
# Epoch 5/10
# 4/4 [==============================] - 0s 65ms/step - loss: 0.4828 - accuracy: 0.9516 - val_loss: 0.4816 - val_accuracy: 0.8966
# Epoch 6/10
# 4/4 [==============================] - 0s 56ms/step - loss: 0.4216 - accuracy: 0.9516 - val_loss: 0.3698 - val_accuracy: 0.9655
# Epoch 7/10
# ...

# %%
model.evaluate(test_ds)
# Out:
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1252 - accuracy: 0.9792
# [0.1252070665359497, 0.9791666865348816]

# %%
import numpy

plt.figure(figsize=(10,10))
for images, labels in test_ds.take(1):
  classifications = model(images)
  print(classifications)
# Out:
# tf.Tensor(
# [[ 8.42782795e-01  3.14277029e+00 -8.68503189e+00]
#  [ 1.04365873e+00  1.60350311e+00 -5.55252504e+00]
#  [ 1.32650816e+00  3.61537552e+00 -1.04533825e+01]
#  [ 1.02298379e+00  2.14687324e+00 -6.76561642e+00]
#  [ 5.11465311e+00 -7.34115064e-01 -8.64860153e+00]
#  [ 4.57925749e+00 -7.34694839e-01 -8.01304626e+00]
#  [ 7.31366456e-01  3.14301944e+00 -7.89859200e+00]
#  [-2.15817448e-02  4.14293814e+00 -9.03373814e+00]
#  [ 2.99902439e-01  3.55037904e+00 -8.39238358e+00]
#  [ 2.63916887e-03  4.16247177e+00 -9.11682129e+00]
#  [ 9.90557611e-01  2.80897427e+00 -7.70655489e+00]
#  [ 1.93375123e+00  1.80473119e-01 -4.50398064e+00]
#  [ 1.04610789e+00  2.78537107e+00 -8.37363148e+00]
#  [ 3.07719421e+00 -1.18438695e-02 -6.18044329e+00]
#  [ 4.04040432e+00 -7.25100875e-01 -6.68876457e+00]
#  [ 5.32948160e+00 -8.53616297e-01 -9.28219795e+00]
#  [ 2.58923262e-01  3.68222499e+00 -8.63078690e+00]
#  [ 1.29596937e+00  2.95167518e+00 -9.40586662e+00]
# ...

# %%
for i in range(9):
  ax = plt.subplot(3, 3, i+1)
  plt.imshow(images[i].numpy().astype("uint8"))
  index = numpy.argmax(classifications[i])
  plt.title("Pred: " + class_names[index])

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open("model.tflite",'wb') as f:
  f.write(tflite_model)
